# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('max_columns', 100)
# %matplotlib inline

# %%
df_train_raw = pd.read_csv('../input/train.csv')
df_test_raw = pd.read_csv('../input/test.csv')
df_train = df_train_raw.copy()
df_test = df_test_raw.copy()
train_len = len(df_train)

# %%
df_train.head(10)
# Out:
#    id  age            job  marital  education default  balance housing loan  \
# 0   1   39    blue-collar  married  secondary      no     1756     yes   no
# 1   2   51   entrepreneur  married    primary      no     1443      no   no
# 2   3   36     management   single   tertiary      no      436      no   no
# 3   4   63        retired  married  secondary      no      474      no   no
# 4   5   31     management   single   tertiary      no      354      no   no
# 5   6   29    blue-collar   single  secondary      no      260     yes   no
# 6   7   37       services  married  secondary      no       52     yes   no
# 7   8   32     technician   single  secondary      no      230     yes   no
# 8   9   31         admin.   single  secondary      no        0     yes   no
# 9  10   32  self-employed   single   tertiary      no     1815      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular    3   apr       939         1     -1         0  unknown  1
# 1   cellular   18   feb       172        10     -1         0  unknown  1
# 2   cellular   13   apr       567         1    595         2  failure  1
# 3   cellular   25   jan       423         1     -1         0  unknown  1
# 4   cellular   30   apr       502         1      9         2  success  1
# 5    unknown    2   jun       707        14     -1         0  unknown  1
# 6   cellular    6   sep       908         1    185         9  success  1
# 7   cellular   18   may       442         1    266         8  failure  1
# 8   cellular    7   may       895         2    295         2  failure  1
# 9  telephone   10   aug       235         1    102         2  failure  1

# %%
df_test.head(10)
# Out:
#    id  age            job  marital  education default  balance housing loan  \
# 0   1   30     management   single   tertiary      no     1028      no   no
# 1   2   39  self-employed   single   tertiary      no      426      no   no
# 2   3   38     technician   single   tertiary      no     -572     yes  yes
# 3   4   34     technician   single  secondary      no     -476     yes   no
# 4   5   37   entrepreneur  married    primary      no       62      no   no
# 5   6   43       services  married    primary      no      574     yes   no
# 6   7   54     technician  married  secondary      no      324     yes   no
# 7   8   41    blue-collar  married  secondary      no      121     yes   no
# 8   9   52      housemaid  married    primary      no     1466      no  yes
# 9  10   32     management  married  secondary      no     6217     yes  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome
# 0   cellular    4   feb      1294         2     -1         0  unknown
# 1    unknown   18   jun      1029         1     -1         0  unknown
# 2    unknown    5   jun        26        24     -1         0  unknown
# 3    unknown   27   may        92         4     -1         0  unknown
# 4   cellular   31   jul       404         2     -1         0  unknown
# 5   cellular    8   may       140         1     -1         0  unknown
# 6  telephone   13   may        51         1     -1         0  unknown
# 7   cellular   13   may        16         6    176         5    other
# 8   cellular   20   nov       150         1     -1         0  unknown
# 9   cellular   18   nov       486         2    181         2  failure

# %%
df_train.describe().astype(int)
# Out:
#           id    age  balance    day  duration  campaign  pdays  previous  \
# count  27128  27128    27128  27128     27128     27128  27128     27128
# mean   13564     40     1355     15       260         2     40         0
# std     7831     10     3003      8       260         3    100         2
# min        1     18    -6847      1         0         1     -1         0
# 25%     6782     33       72      8       104         1     -1         0
# 50%    13564     39      449     16       182         2     -1         0
# 75%    20346     48     1428     21       323         3     -1         0
# max    27128     95   102127     31      4918        63    871       275
#
#            y
# count  27128
# mean       0
# std        0
# min        0
# 25%        0
# 50%        0
# 75%        0
# max        1

# %%
df_test.describe().astype(int)
# Out:
#           id    age  balance    day  duration  campaign  pdays  previous
# count  18083  18083    18083  18083     18083     18083  18083     18083
# mean    9042     40     1371     15       254         2     39         0
# std     5220     10     3105      8       253         3     99         1
# min        1     18    -8019      1         0         1     -1         0
# 25%     4521     33       72      8       102         1     -1         0
# 50%     9042     39      447     16       178         2     -1         0
# 75%    13562     48     1427     21       314         3     -1         0
# max    18083     95    98417     31      3881        50    854        58

# %%
df_train.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %% [markdown]
# 欠損値なし

# %% [markdown]
# ### プロット用関数

# %%
def plot_dist_num(data, col_name):
    plot_data = data[data[col_name].notnull()].copy()
    plt.figure(figsize=(15,2))
    plt.hist(plot_data[col_name], bins=20)
    plt.title(col_name)
    plt.show()

# %%
def plot_dist_obj(data, col_name):
    plot_data = data[data[col_name].notnull()].copy()
    plt.figure(figsize=(15,2))
    #data[col_name].value_counts().plot(kind='bar')
    sns.countplot(plot_data[col_name])
    plt.title(col_name)
    plt.show()

# %%
def plot_dist(data):
    num_cols = data.select_dtypes(include='number').columns
    obj_cols = data.select_dtypes(exclude='number').columns
    
    for col_name in num_cols:
        plot_dist_num(data, col_name)
    
    for col_name in obj_cols:
        plot_dist_obj(data, col_name)

# %%
def plot_vs_num(data, col_name, y_name):
    plot_data = data[data[col_name].notnull()].copy()
    plt.figure(figsize=(15,2))
    col_bin = pd.cut(plot_data[col_name], bins=10)
    sns.barplot(x=col_bin, y=plot_data[y_name])
    plt.ylabel(y_name)
    plt.title(col_name + '_bin')
    plt.show()

# %%
def plot_vs_obj(data, col_name, y_name):
    plot_data = data[data[col_name].notnull()].copy()
    plt.figure(figsize=(15,2))
    sns.barplot(data = plot_data, y=y_name, x=col_name)
    #plt.xlabel(col_name)
    plt.ylabel(y_name)
    plt.title(col_name)
    plt.show()

# %%
def plot_vs(data, y_name):
    num_cols = data.select_dtypes(include='number').columns
    obj_cols = data.select_dtypes(exclude='number').columns
    
    for col_name in num_cols:
        plot_vs_num(data, col_name, y_name)
    
    for col_name in obj_cols:
        plot_vs_obj(data, col_name, y_name)

# %%
def plot_box(data, col_name):
    plt.figure(figsize=(15,2))
    sns.boxplot(data = data, x='y', y=col_name)
    plt.ylabel(col_name)
    plt.xlabel('y')
    plt.title(col_name)

# %%
def plot_violin(data, col_name):
    plt.figure(figsize=(15,2))
    sns.violinplot(data = data, x='y', y=col_name)
    plt.ylabel(col_name)
    plt.xlabel('y')
    plt.title(col_name)

# %%
train_num_cols = df_train.select_dtypes(include='number').columns
train_obj_cols = df_train.select_dtypes(exclude='number').columns

# %% [markdown]
# ## まとめてプロット

# %% [markdown]
# #### y vs. 連続データ (violinplot)

# %% [raw]
# for col_name in train_num_cols:
#     plot_violin(df_train, col_name)

# %% [markdown]
# #### y vs. 連続データ (boxplot)

# %%
for col_name in train_num_cols:
    plot_box(df_train, col_name)

# %% [markdown]
# ## 外れ値削除後

# %%
df_out = pd.read_csv('./trian_without_outliers.csv')

# %%
for col_name in train_num_cols:
    plot_box(df_out, col_name)

# %%
df_plot = df_out
for col_name in df_plot.columns:
    dtype = df_plot[col_name].dtype
    if (dtype == 'object'):
        plot_dist_obj(df_plot, col_name)
        plot_vs_obj(df_plot, col_name, 'y')
        print('-----------------------------------------------------------')
    else:
        plot_dist_num(df_plot, col_name)
        plot_vs_num(df_plot, col_name, 'y')
        print('-----------------------------------------------------------')
# Out:
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------

# %%
df_out.loc[(df_out.month=='mar') & (df_out.day==8)]
# Out:
#           id  age            job   marital  education default  balance  \
# 756      757   34         admin.   married   tertiary      no      798
# 5635    5637   59     unemployed   married  secondary      no      957
# 7058    7060   31     technician   married   tertiary      no     1570
# 8724    8726   33     management    single   tertiary      no      224
# 10556  10559   32     unemployed    single    primary      no     1429
# 13493  13496   49  self-employed  divorced   tertiary      no     3293
# 18996  19000   38        student    single    unknown      no      444
# 25602  25606   64     unemployed  divorced  secondary      no      588
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 756       yes   no  cellular    8   mar       284         2     -1         0
# 5635       no   no  cellular    8   mar       301         1     89         2
# 7058      yes   no  cellular    8   mar       277         4    286         1
# 8724       no   no  cellular    8   mar       241         2     -1         0
# 10556      no   no  cellular    8   mar       150         4     -1         0
# 13493      no   no  cellular    8   mar       111         3    585         6
# 18996      no   no  cellular    8   mar       157         3    206         6
# 25602      no   no  cellular    8   mar       409         1     -1         0
#
#       poutcome  y
# 756    unknown  0
# 5635   success  1
# 7058   failure  1
# 8724   unknown  1
# 10556  unknown  0
# 13493    other  0
# 18996  success  0
# 25602  unknown  1

# %%
df_out.pdays.head(10)
# Out:
# 0     -1
# 1     -1
# 2    595
# 3     -1
# 4      9
# 5     -1
# 6    185
# 7    266
# 8    295
# 9    102
# Name: pdays, dtype: int64

# %%
df_out.loc[(df_out.poutcome=='unknown') & (df_out.pdays!=-1)]
# Out:
#           id  age         job  marital  education default  balance housing  \
# 6169    6171   26      admin.   single  secondary      no      338      no
# 24984  24988   61     retired  married   tertiary      no     3140     yes
# 25026  25030   39  management  married   tertiary      no      184      no
# 26766  26770   37  management  married  secondary      no      209      no
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 6169    no  cellular   29   oct       209         1    188         2  unknown
# 24984  yes  cellular    6   aug       975         4     98         1  unknown
# 25026   no  cellular   15   oct       206         1    168         5  unknown
# 26766   no  cellular   14   oct       183         3    528         7  unknown
#
#        y
# 6169   1
# 24984  1
# 25026  0
# 26766  0

# %%
df_out.loc[(df_out.poutcome=='unknown') & (df_out.pdays!=-1), 'poutcome'] = 'other'

# %%
df_out[df_out.pdays==-1]
# Out:
#           id  age            job   marital  education default  balance  \
# 0          1   39    blue-collar   married  secondary      no     1756
# 1          2   51   entrepreneur   married    primary      no     1443
# 3          4   63        retired   married  secondary      no      474
# 5          6   29    blue-collar    single  secondary      no      260
# 10        11   35  self-employed    single   tertiary      no      353
# 11        12   34     technician  divorced  secondary      no     1451
# 12        13   34         admin.    single   tertiary      no      625
# 14        15   38    blue-collar   married    primary      no     5839
# 15        16   71     technician   married   tertiary      no      383
# 16        17   62     management   married   tertiary      no      557
# 18        19   46    blue-collar   married    primary      no      369
# 19        20   29         admin.    single   tertiary      no       89
# 20        21   28  self-employed   married   tertiary      no      112
# 21        22   67        retired   married    primary      no      708
# 22        23   42     management   married   tertiary      no        4
# 23        24   33         admin.  divorced  secondary      no      420
# 24        25   39       services    single  secondary      no      158
# 25        26   57        retired  divorced   tertiary      no       66
# 26        27   43     management    single   tertiary      no        0
# 27        28   46       services  divorced    unknown      no      973
# 28        29   31    blue-collar   married    primary      no      -81
# 29        30   36     technician    single  secondary      no      524
# 31        32   52         admin.    single    unknown      no     2227
# 32        33   30  self-employed    single   tertiary      no      800
# 35        36   56     management   married   tertiary      no      171
# 36        37   48     management   married  secondary      no     2204
# 37        38   30     technician    single  secondary      no      601
# 38        39   60      housemaid  divorced    primary      no     1412
# 39        40   32     technician   married  secondary      no     1337
# 40        41   31     management    single  secondary     yes        0
# ...      ...  ...            ...       ...        ...     ...      ...
# 27090  27094   32     management   married   tertiary      no     1683
# 27091  27095   46    blue-collar   married  secondary      no     1004
# 27092  27096   44     unemployed   married    primary      no       51
# 27093  27097   34     management    single   tertiary      no        3
# 27094  27098   28   entrepreneur   married  secondary      no      422
# 27095  27099   31         admin.  divorced  secondary      no      525
# 27096  27100   29    blue-collar    single  secondary      no        0
# 27097  27101   46    blue-collar   married    primary      no      222
# 27098  27102   32    blue-collar   married  secondary      no       14
# 27099  27103   38     management   married   tertiary      no      551
# 27100  27104   36   entrepreneur   married   tertiary      no      247
# 27101  27105   59     management   married  secondary      no    -1246
# 27102  27106   44     management    single   tertiary      no     5063
# 27103  27107   40     management   married  secondary      no      752
# 27104  27108   35         admin.   married  secondary      no      348
# 27105  27109   33    blue-collar   married  secondary      no      661
# 27106  27110   43       services   married  secondary      no      823
# 27107  27111   51     management   married   tertiary      no      941
# 27108  27112   50     unemployed   married  secondary      no     3478
# 27109  27113   45    blue-collar   married    primary      no        0
# 27110  27114   41   entrepreneur   married   tertiary      no     1065
# 27111  27115   43    blue-collar   married    primary      no      -93
# 27113  27117   45        retired  divorced  secondary      no      187
# 27114  27118   30     management    single  secondary      no       19
# 27116  27120   27     technician   married   tertiary      no    10451
# 27118  27122   37  self-employed   married   tertiary      no     2211
# 27119  27123   59  self-employed  divorced   tertiary      no     2979
# 27121  27125   34       services    single  secondary      no      719
# 27122  27126   36    blue-collar    single    primary      no       49
# 27123  27127   33      housemaid   married    primary      no      209
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 0         yes   no   cellular    3   apr       939         1     -1         0
# 1          no   no   cellular   18   feb       172        10     -1         0
# 3          no   no   cellular   25   jan       423         1     -1         0
# 5         yes   no    unknown    2   jun       707        14     -1         0
# 10         no   no   cellular   12   aug       582         1     -1         0
# 11        yes   no    unknown   30   may      1097        15     -1         0
# 12         no  yes    unknown   31   aug        34         1     -1         0
# 14        yes   no    unknown    4   jun       984         2     -1         0
# 15         no   no   cellular   27   apr       388         3     -1         0
# 16         no   no   cellular   14   aug       185         1     -1         0
# 18        yes   no    unknown   13   may       916         2     -1         0
# 19        yes   no   cellular   22   jul       120         1     -1         0
# 20        yes  yes   cellular    5   may       145         1     -1         0
# 21         no   no   cellular   11   sep        96         2     -1         0
# 22        yes   no   cellular   17   jul       795         1     -1         0
# 23        yes   no  telephone    6   feb       112         2     -1         0
# 24        yes   no    unknown    6   jun       354         2     -1         0
# 25        yes   no   cellular   11   may       798         2     -1         0
# 26         no   no   cellular   11   aug       155         2     -1         0
# 27         no   no   cellular    2   feb       297         1     -1         0
# 28        yes   no   cellular   22   jul       261         1     -1         0
# 29        yes   no   cellular    8   apr        95         1     -1         0
# 31         no   no   cellular   24   feb       242         2     -1         0
# 32         no   no    unknown    6   may        95         2     -1         0
# 35         no  yes  telephone   17   jul       610         2     -1         0
# 36        yes   no   cellular   12   may        45         1     -1         0
# 37         no   no   cellular   27   feb       154         1     -1         0
# 38         no   no   cellular   22   jul       127         4     -1         0
# 39         no   no    unknown   26   may       368         6     -1         0
# 40         no   no   cellular   18   nov       129         2     -1         0
# ...       ...  ...        ...  ...   ...       ...       ...    ...       ...
# 27090     yes  yes   cellular   20   apr        72         2     -1         0
# 27091     yes   no    unknown   15   may        34         1     -1         0
# 27092      no   no   cellular   30   jul       289         4     -1         0
# 27093      no   no   cellular    5   feb        16         5     -1         0
# 27094     yes   no    unknown   19   may       394         2     -1         0
# 27095      no  yes  telephone   19   nov       278         7     -1         0
# 27096     yes   no    unknown   29   may       106         4     -1         0
# 27097      no   no   cellular    8   aug        71         2     -1         0
# 27098     yes   no    unknown    2   jun       171         1     -1         0
# 27099     yes   no    unknown   12   may      1875         4     -1         0
# 27100      no   no   cellular   17   apr       351         1     -1         0
# 27101      no   no  telephone   29   jul       175         2     -1         0
# 27102      no   no   cellular   27   oct       418         2     -1         0
# 27103      no  yes    unknown   17   jun       717         1     -1         0
# 27104     yes  yes   cellular   15   jul       323         3     -1         0
# 27105     yes   no   cellular   18   jul       968         1     -1         0
# 27106     yes   no    unknown   14   may       293         3     -1         0
# 27107     yes  yes   cellular   18   jul       252         6     -1         0
# 27108     yes   no    unknown   13   may       342         3     -1         0
# 27109     yes   no  telephone   24   jul        32         1     -1         0
# 27110     yes  yes    unknown   29   may       553         1     -1         0
# 27111     yes   no    unknown   26   may       402         2     -1         0
# 27113     yes   no   cellular   11   may        82         2     -1         0
# 27114      no   no   cellular   26   aug       191         2     -1         0
# 27116     yes   no   cellular    2   feb        45         1     -1         0
# 27118     yes   no   cellular   25   may       143         1     -1         0
# 27119     yes   no   cellular   21   jul       118         3     -1         0
# 27121     yes   no    unknown   15   may       362         3     -1         0
# 27122     yes   no    unknown    8   may       405         1     -1         0
# 27123      no   no   cellular   12   aug        76         4     -1         0
#
#       poutcome  y
# 0      unknown  1
# 1      unknown  1
# 3      unknown  1
# 5      unknown  1
# 10     unknown  1
# 11     unknown  1
# 12     unknown  1
# 14     unknown  1
# 15     unknown  1
# 16     unknown  1
# 18     unknown  1
# 19     unknown  0
# 20     unknown  0
# 21     unknown  0
# 22     unknown  1
# 23     unknown  0
# 24     unknown  0
# 25     unknown  0
# 26     unknown  0
# 27     unknown  0
# 28     unknown  0
# 29     unknown  0
# 31     unknown  1
# 32     unknown  0
# 35     unknown  0
# 36     unknown  0
# 37     unknown  0
# 38     unknown  0
# 39     unknown  0
# 40     unknown  0
# ...        ... ..
# 27090  unknown  0
# 27091  unknown  0
# 27092  unknown  0
# 27093  unknown  0
# 27094  unknown  0
# 27095  unknown  0
# 27096  unknown  0
# 27097  unknown  0
# 27098  unknown  0
# 27099  unknown  0
# 27100  unknown  0
# 27101  unknown  0
# 27102  unknown  1
# 27103  unknown  0
# 27104  unknown  0
# 27105  unknown  1
# 27106  unknown  0
# 27107  unknown  0
# 27108  unknown  0
# 27109  unknown  0
# 27110  unknown  0
# 27111  unknown  0
# 27113  unknown  0
# 27114  unknown  0
# 27116  unknown  0
# 27118  unknown  0
# 27119  unknown  0
# 27121  unknown  0
# 27122  unknown  0
# 27123  unknown  0
#
# [22144 rows x 18 columns]

# %%
df_out[df_out.pdays==0]
# Out:
# Empty DataFrame
# Columns: [id, age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, y]
# Index: []

# %%
df_out[df_out.pdays==1]
# Out:
#           id  age           job  marital  education default  balance housing  \
# 693      694   45   blue-collar  married  secondary      no      640     yes
# 5182    5184   38    management  married   tertiary      no     1199      no
# 10293  10296   42    management  married   tertiary      no      372     yes
# 11496  11499   41   blue-collar  married    primary      no      201     yes
# 12563  12566   42        admin.  married  secondary      no      641      no
# 15805  15808   33    technician  married  secondary      no     1026      no
# 17997  18001   34        admin.  married   tertiary      no       69      no
# 18992  18996   46  entrepreneur  married  secondary      no      122      no
# 20351  20355   78       retired  married    unknown      no       38      no
# 21995  21999   29    management  married   tertiary      no      198     yes
# 22519  22523   62       retired  married  secondary      no      569      no
# 26363  26367   35    management   single   tertiary      no      747      no
#
#       loan    contact  day month  duration  campaign  pdays  previous  \
# 693     no   cellular    5   may       214         1      1         1
# 5182    no   cellular    4   aug       178         1      1         1
# 10293   no   cellular    4   aug       153         3      1         2
# 11496   no   cellular    4   feb        69         1      1         1
# 12563   no   cellular    4   aug       111         1      1         1
# 15805   no   cellular    4   aug        87         1      1         5
# 17997  yes   cellular    4   aug       120         3      1         6
# 18992   no   cellular    6   feb      1047         2      1         7
# 20351   no  telephone    4   aug       156         1      1         3
# 21995   no   cellular    4   aug       453         1      1         1
# 22519   no   cellular    4   aug       288         1      1         8
# 26363   no   cellular    4   aug        91         1      1         6
#
#       poutcome  y
# 693    success  0
# 5182   success  1
# 10293  success  1
# 11496  success  0
# 12563    other  0
# 15805  failure  0
# 17997  success  1
# 18992  failure  0
# 20351    other  0
# 21995  failure  0
# 22519  success  1
# 26363    other  0

# %%
plot_dist_num(df_out[df_out.pdays!=-1], 'pdays')

# %%
df_plot = df_out[df_out.pdays!=-1].copy()
df_plot['month'] = df_plot['month'].map({'jan':1,
                       'feb':2,
                       'mar':3,
                       'apr':4,
                       'may':5,
                       'jun':6,
                       'jul':7,
                       'aug':8,
                       'sep':9,
                       'oct':10,
                       'nov':11,
                       'dec':12
                      })
plt.figure(figsize=(15,5))
sns.violinplot(y=df_plot['pdays'], x=df_plot['month'])

# %%
df_new[df_new.duration==0]
# Out:
#           id  age           job  marital  education default  balance housing  \
# 12032  12035   53    management  married    primary      no      351     yes
# 13449  13452   31  entrepreneur  married  secondary      no      162     yes
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 12032   no   unknown   27   may         0         4     -1         0  unknown
# 13449  yes  cellular   11   may         0         2     -1         0  unknown
#
#        y
# 12032  0
# 13449  0

# %%
df_new = pd.read_csv('./df_new_1.csv')

# %%
for col_name in df_new.columns:
    dtype = df_new[col_name].dtype
    if (dtype == 'int64' or dtype == 'object'):
        plot_dist_obj(df_new, col_name)
        plot_vs_obj(df_new, col_name, 'y')
        print('-----------------------------------------------------------')
    elif dtype == 'float':
        plot_dist_num(df_new, col_name)
        plot_vs_num(df_new, col_name, 'y')
        print('-----------------------------------------------------------')
# Out:
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------
# -----------------------------------------------------------

# %%
plot_dist(df_new)

# %%
plot_vs(df_new, 'y')
